# %% [markdown]
# # Processing necessary data for 'Demographics' Dashboard visualization
# _by Juan Mamani-Rojas_ _([LinkedIn](https://linkedin.com/in/jjvmr))_

# %% [markdown]
# ## Steps
# ### 1. Import Necessary Libraries and dependencies
#
# ```
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
# Copy the code above in the cell below if needed.

# %%
# Paste code here

# %% [markdown]
# ### 2. Read csv file from provided url.
# For this task, we only want the necessary columns that will provide us with the best visualizations for demographics.

# %%
df = pd.read_csv("D:/_JJProjects/JupyterProject/survey_data.csv")

columns_to_keep = [
    "ResponseId",
    "Country",
    "EdLevel",
    "Age"
]

# Keep only these columns
# df = df[columns_to_keep]

# Or keep only a couple of columns manually (instead of using the list above)
df = df[["ResponseId","Age"]]
# Out:
# array(['35-44 years old', '45-54 years old', '25-34 years old',
#        '55-64 years old', '18-24 years old', 'Under 18 years old',
#        '65 years or older', 'Prefer not to say'], dtype=object)

# %%
# Quickly verify the loaded data and its structure
df.head()
# Out:
#    ResponseId                                            Country  \
# 0           2  United Kingdom of Great Britain and Northern I...
# 1           3  United Kingdom of Great Britain and Northern I...
# 2          10                                             Serbia
# 3          11                           United States of America
# 4          12                                             Poland
#
#                                            EdLevel              Age
# 0     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  35-44 years old
# 1  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  45-54 years old
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  35-44 years old
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  35-44 years old
# 4   Professional degree (JD, MD, Ph.D, Ed.D, etc.)  45-54 years old

# %% [markdown]
# ### 3. Save df into a csv file
# These tables did not need any pre-processing as the visualiation we will be creating are between the number of responses against a demographics variable.

# %%
df.to_csv("C:/User/your_folder/demdata.csv", index=False)

# %% [markdown]
# ### 4. Upload df into new csv
# Once you have obtained the data you need, upload it into Google Looker or IBM Cognos Analytics and start creating your own visualizations!
#
# # Thank you!
